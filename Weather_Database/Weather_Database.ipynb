# %%
#Import initial libraries.
import numpy as np
import pandas as pd
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 701

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
         
    
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ostrovnoy
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | benguela
# Processing Record 4 of Set 1 | college
# Processing Record 5 of Set 1 | kavieng
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | vila franca do campo
# Processing Record 8 of Set 1 | tazovskiy
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | bengkulu
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | lompoc
# Processing Record 13 of Set 1 | iqaluit
# Processing Record 14 of Set 1 | mar del plata
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | torrijos
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | wanning
# Processing Record 20 of Set 1 | progreso
# Processing Record 21 of Set 1 | kirensk
# Processing Record 22 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | upernavik
# Processing Record 25 of Set 1 | lithakia
# Processing Record 26 of Set 1 | pokhara
# Processing Record 27 of Set 1 | kaitong
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | el vigia
# Processing Record 30 of Set 1 | constitucion
# Processing Record 31 of Set 1 | klamath falls
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | airai
# Processing Record 35 of Set 1 | rawson
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | souillac
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | alausi
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | kloulklubed
# Processing Record 47 of Set 1 | coihaique
# Processing Record 48 of Set 1 | yulara
# Processing Record 49 of Set 1 | egvekinot
# Processing Record 50 of Set 1 | syava
# Processing Record 1 of Set 2 | eydhafushi
# Processing Record 2 of Set 2 | namatanai
# Processing Record 3 of Set 2 | flinders
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | mufumbwe
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | saint-philippe
# Processing Record 8 of Set 2 | zaragoza
# Processing Record 9 of Set 2 | hilo
# Processing Record 10 of Set 2 | mahebourg
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | svetlogorsk
# Processing Record 13 of Set 2 | andilamena
# Processing Record 14 of Set 2 | tuktoyaktuk
# Processing Record 15 of Set 2 | ribeira grande
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | deputatskiy
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | ghogha
# Processing Record 22 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | busselton
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 27 of Set 2 | nikolskoye
# Processing Record 28 of Set 2 | mackay
# Processing Record 29 of Set 2 | coquimbo
# Processing Record 30 of Set 2 | tromso
# Processing Record 31 of Set 2 | olavarria
# Processing Record 32 of Set 2 | narsaq
# Processing Record 33 of Set 2 | nisia floresta
# Processing Record 34 of Set 2 | longyan
# Processing Record 35 of Set 2 | tual
# Processing Record 36 of Set 2 | nanortalik
# Processing Record 37 of Set 2 | pisco
# Processing Record 38 of Set 2 | jalu
# Processing Record 39 of Set 2 | kavaratti
# Processing Record 40 of Set 2 | alice springs
# Processing Record 41 of Set 2 | seymchan
# Processing Record 42 of Set 2 | geraldton
# Processing Record 43 of Set 2 | tiksi
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | vostok
# Processing Record 46 of Set 2 | monte azul
# Processing Record 47 of Set 2 | bathsheba
# Processing Record 48 of Set 2 | pandan niog
# Processing Record 49 of Set 2 | rancho palos verdes
# Processing Record 50 of Set 2 | victoria
# Processing Record 1 of Set 3 | eyl
# Processing Record 2 of Set 3 | olafsvik
# Processing Record 3 of Set 3 | talnakh
# Processing Record 4 of Set 3 | saldanha
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | grande-riviere
# City not found. Skipping...
# Processing Record 7 of Set 3 | port keats
# Processing Record 8 of Set 3 | port alfred
# Processing Record 9 of Set 3 | bluff
# Processing Record 10 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 3 | torbay
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | tanout
# Processing Record 14 of Set 3 | nouakchott
# Processing Record 15 of Set 3 | soe
# Processing Record 16 of Set 3 | jamestown
# Processing Record 17 of Set 3 | yerbogachen
# Processing Record 18 of Set 3 | nizhnyaya tavda
# Processing Record 19 of Set 3 | zhezkazgan
# Processing Record 20 of Set 3 | kodiak
# Processing Record 21 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 3 | hirara
# Processing Record 23 of Set 3 | klaksvik
# Processing Record 24 of Set 3 | caravelas
# Processing Record 25 of Set 3 | steinbach
# Processing Record 26 of Set 3 | tilichiki
# Processing Record 27 of Set 3 | abu samrah
# Processing Record 28 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 3 | taree
# Processing Record 30 of Set 3 | port lincoln
# Processing Record 31 of Set 3 | ouesso
# Processing Record 32 of Set 3 | ponta do sol
# Processing Record 33 of Set 3 | srednekolymsk
# Processing Record 34 of Set 3 | castro
# Processing Record 35 of Set 3 | gat
# Processing Record 36 of Set 3 | broome
# Processing Record 37 of Set 3 | hofn
# Processing Record 38 of Set 3 | chuy
# Processing Record 39 of Set 3 | cortez
# Processing Record 40 of Set 3 | pemba
# Processing Record 41 of Set 3 | norman wells
# Processing Record 42 of Set 3 | tanushimaru
# Processing Record 43 of Set 3 | awbari
# Processing Record 44 of Set 3 | ulety
# Processing Record 45 of Set 3 | yei
# Processing Record 46 of Set 3 | zhanaozen
# Processing Record 47 of Set 3 | juneau
# Processing Record 48 of Set 3 | cidreira
# Processing Record 49 of Set 3 | hualmay
# Processing Record 50 of Set 3 | wainwright
# Processing Record 1 of Set 4 | dabhol
# Processing Record 2 of Set 4 | coahuayana
# Processing Record 3 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 4 | fujin
# Processing Record 5 of Set 4 | prince rupert
# Processing Record 6 of Set 4 | omboue
# Processing Record 7 of Set 4 | kahului
# Processing Record 8 of Set 4 | nome
# Processing Record 9 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 10 of Set 4 | isangel
# Processing Record 11 of Set 4 | henties bay
# Processing Record 12 of Set 4 | bethel
# Processing Record 13 of Set 4 | tsienyane
# City not found. Skipping...
# Processing Record 14 of Set 4 | longyearbyen
# Processing Record 15 of Set 4 | lasa
# Processing Record 16 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 4 | sturgeon bay
# Processing Record 18 of Set 4 | bubaque
# Processing Record 19 of Set 4 | pitsunda
# Processing Record 20 of Set 4 | vila velha
# Processing Record 21 of Set 4 | vardo
# Processing Record 22 of Set 4 | lieksa
# Processing Record 23 of Set 4 | bambous virieux
# Processing Record 24 of Set 4 | palana
# Processing Record 25 of Set 4 | omsukchan
# Processing Record 26 of Set 4 | thinadhoo
# Processing Record 27 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 4 | necochea
# Processing Record 29 of Set 4 | shakawe
# Processing Record 30 of Set 4 | tramandai
# Processing Record 31 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 32 of Set 4 | san cristobal
# Processing Record 33 of Set 4 | sergeyevka
# Processing Record 34 of Set 4 | esso
# Processing Record 35 of Set 4 | los llanos de aridane
# Processing Record 36 of Set 4 | fort nelson
# Processing Record 37 of Set 4 | kindu
# Processing Record 38 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 39 of Set 4 | waingapu
# Processing Record 40 of Set 4 | yatou
# Processing Record 41 of Set 4 | samarai
# Processing Record 42 of Set 4 | wuhan
# Processing Record 43 of Set 4 | tarauaca
# Processing Record 44 of Set 4 | falmouth
# Processing Record 45 of Set 4 | acarau
# Processing Record 46 of Set 4 | olinda
# Processing Record 47 of Set 4 | boddam
# Processing Record 48 of Set 4 | smithers
# Processing Record 49 of Set 4 | altay
# Processing Record 50 of Set 4 | sao filipe
# Processing Record 1 of Set 5 | severo-kurilsk
# Processing Record 2 of Set 5 | tuatapere
# Processing Record 3 of Set 5 | shimoda
# Processing Record 4 of Set 5 | abay
# Processing Record 5 of Set 5 | marshall
# Processing Record 6 of Set 5 | new norfolk
# Processing Record 7 of Set 5 | paamiut
# Processing Record 8 of Set 5 | maragogi
# Processing Record 9 of Set 5 | peniche
# Processing Record 10 of Set 5 | merauke
# Processing Record 11 of Set 5 | yefira
# City not found. Skipping...
# Processing Record 12 of Set 5 | harper
# Processing Record 13 of Set 5 | provideniya
# Processing Record 14 of Set 5 | varzea da palma
# Processing Record 15 of Set 5 | trofors
# Processing Record 16 of Set 5 | tasiilaq
# Processing Record 17 of Set 5 | tutoia
# Processing Record 18 of Set 5 | okoneshnikovo
# Processing Record 19 of Set 5 | bordighera
# Processing Record 20 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 5 | banyo
# Processing Record 22 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 5 | sinnamary
# Processing Record 24 of Set 5 | ruidoso
# Processing Record 25 of Set 5 | mugango
# Processing Record 26 of Set 5 | balkhash
# Processing Record 27 of Set 5 | tondano
# Processing Record 28 of Set 5 | faanui
# Processing Record 29 of Set 5 | anshun
# Processing Record 30 of Set 5 | slave lake
# Processing Record 31 of Set 5 | kondinskoye
# Processing Record 32 of Set 5 | hasaki
# Processing Record 33 of Set 5 | hovd
# Processing Record 34 of Set 5 | taperoa
# Processing Record 35 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 5 | ocara
# Processing Record 37 of Set 5 | makakilo city
# Processing Record 38 of Set 5 | cherskiy
# Processing Record 39 of Set 5 | marawi
# Processing Record 40 of Set 5 | portland
# Processing Record 41 of Set 5 | port hardy
# Processing Record 42 of Set 5 | te anau
# Processing Record 43 of Set 5 | dimitrovgrad
# Processing Record 44 of Set 5 | touros
# Processing Record 45 of Set 5 | cabo san lucas
# Processing Record 46 of Set 5 | banjar
# Processing Record 47 of Set 5 | pangnirtung
# Processing Record 48 of Set 5 | tema
# Processing Record 49 of Set 5 | margate
# Processing Record 50 of Set 5 | ixtapa
# Processing Record 1 of Set 6 | sangre grande
# Processing Record 2 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 6 | marzuq
# Processing Record 4 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 6 | sampit
# Processing Record 6 of Set 6 | alexandria
# Processing Record 7 of Set 6 | argostolion
# Processing Record 8 of Set 6 | the valley
# Processing Record 9 of Set 6 | abeche
# Processing Record 10 of Set 6 | obihiro
# Processing Record 11 of Set 6 | muskogee
# Processing Record 12 of Set 6 | nargana
# Processing Record 13 of Set 6 | carnot
# Processing Record 14 of Set 6 | oistins
# Processing Record 15 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 6 | sao paulo de olivenca
# Processing Record 17 of Set 6 | mbala
# Processing Record 18 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 6 | oytal
# Processing Record 20 of Set 6 | armidale
# Processing Record 21 of Set 6 | pevek
# Processing Record 22 of Set 6 | zvishavane
# Processing Record 23 of Set 6 | vao
# Processing Record 24 of Set 6 | richards bay
# Processing Record 25 of Set 6 | sitka
# Processing Record 26 of Set 6 | saint george
# Processing Record 27 of Set 6 | hami
# Processing Record 28 of Set 6 | nantucket
# Processing Record 29 of Set 6 | ilulissat
# Processing Record 30 of Set 6 | kaeo
# Processing Record 31 of Set 6 | okhotsk
# Processing Record 32 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 6 | taitung
# Processing Record 34 of Set 6 | zapolyarnyy
# Processing Record 35 of Set 6 | mizdah
# Processing Record 36 of Set 6 | yumen
# Processing Record 37 of Set 6 | arlit
# Processing Record 38 of Set 6 | namie
# Processing Record 39 of Set 6 | najran
# Processing Record 40 of Set 6 | wattegama
# Processing Record 41 of Set 6 | dzitas
# Processing Record 42 of Set 6 | east london
# Processing Record 43 of Set 6 | takoradi
# Processing Record 44 of Set 6 | kieta
# Processing Record 45 of Set 6 | forraskut
# Processing Record 46 of Set 6 | esperance
# Processing Record 47 of Set 6 | hede
# Processing Record 48 of Set 6 | verkhoyansk
# Processing Record 49 of Set 6 | palmer
# Processing Record 50 of Set 6 | thisted
# Processing Record 1 of Set 7 | shingu
# Processing Record 2 of Set 7 | launceston
# Processing Record 3 of Set 7 | khandbari
# Processing Record 4 of Set 7 | batemans bay
# Processing Record 5 of Set 7 | port-cartier
# Processing Record 6 of Set 7 | kentau
# Processing Record 7 of Set 7 | chagoda
# Processing Record 8 of Set 7 | otane
# Processing Record 9 of Set 7 | lorengau
# Processing Record 10 of Set 7 | ambilobe
# Processing Record 11 of Set 7 | flin flon
# Processing Record 12 of Set 7 | marsa matruh
# Processing Record 13 of Set 7 | lakefield
# Processing Record 14 of Set 7 | liwale
# Processing Record 15 of Set 7 | namibe
# Processing Record 16 of Set 7 | san juan
# Processing Record 17 of Set 7 | agadez
# Processing Record 18 of Set 7 | teguldet
# Processing Record 19 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 7 | meulaboh
# Processing Record 21 of Set 7 | fort morgan
# Processing Record 22 of Set 7 | muroto
# Processing Record 23 of Set 7 | moron
# Processing Record 24 of Set 7 | carutapera
# Processing Record 25 of Set 7 | hay river
# Processing Record 26 of Set 7 | grindavik
# Processing Record 27 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 7 | mount gambier
# Processing Record 29 of Set 7 | fairbanks
# Processing Record 30 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 31 of Set 7 | sadiqabad
# Processing Record 32 of Set 7 | douchy-les-mines
# Processing Record 33 of Set 7 | gamba
# Processing Record 34 of Set 7 | cabedelo
# Processing Record 35 of Set 7 | solnechnyy
# Processing Record 36 of Set 7 | le port
# Processing Record 37 of Set 7 | sibolga
# Processing Record 38 of Set 7 | ornskoldsvik
# Processing Record 39 of Set 7 | pandaria
# Processing Record 40 of Set 7 | pocone
# Processing Record 41 of Set 7 | grand gaube
# Processing Record 42 of Set 7 | myitkyina
# Processing Record 43 of Set 7 | marienburg
# Processing Record 44 of Set 7 | entre rios
# Processing Record 45 of Set 7 | sanchez
# Processing Record 46 of Set 7 | bairiki
# Processing Record 47 of Set 7 | angoche
# Processing Record 48 of Set 7 | axim
# Processing Record 49 of Set 7 | hailar
# Processing Record 50 of Set 7 | vikulovo
# Processing Record 1 of Set 8 | cayenne
# Processing Record 2 of Set 8 | mawlaik
# Processing Record 3 of Set 8 | saint anthony
# Processing Record 4 of Set 8 | itarema
# Processing Record 5 of Set 8 | florence
# Processing Record 6 of Set 8 | dalvik
# Processing Record 7 of Set 8 | codrington
# Processing Record 8 of Set 8 | fecamp
# Processing Record 9 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 10 of Set 8 | ginda
# Processing Record 11 of Set 8 | voskresenskoye
# Processing Record 12 of Set 8 | aguining
# Processing Record 13 of Set 8 | lovozero
# Processing Record 14 of Set 8 | maningrida
# Processing Record 15 of Set 8 | bure
# Processing Record 16 of Set 8 | volosovo
# Processing Record 17 of Set 8 | sabang
# Processing Record 18 of Set 8 | anchorage
# Processing Record 19 of Set 8 | turbat
# Processing Record 20 of Set 8 | churapcha
# Processing Record 21 of Set 8 | maralal
# Processing Record 22 of Set 8 | kamsack
# Processing Record 23 of Set 8 | roseburg
# Processing Record 24 of Set 8 | yangjiang
# Processing Record 25 of Set 8 | robinson
# Processing Record 26 of Set 8 | mildura
# Processing Record 27 of Set 8 | bonthe
# Processing Record 28 of Set 8 | poum
# Processing Record 29 of Set 8 | padang
# Processing Record 30 of Set 8 | dali
# Processing Record 31 of Set 8 | sabha
# Processing Record 32 of Set 8 | bayangol
# Processing Record 33 of Set 8 | ugoofaaru
# Processing Record 34 of Set 8 | mango
# Processing Record 35 of Set 8 | cuamba
# Processing Record 36 of Set 8 | lazaro cardenas
# Processing Record 37 of Set 8 | alakurtti
# Processing Record 38 of Set 8 | ialibu
# Processing Record 39 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 8 | rafai
# Processing Record 41 of Set 8 | maceio
# Processing Record 42 of Set 8 | mahajanga
# Processing Record 43 of Set 8 | domoni
# Processing Record 44 of Set 8 | presidencia roque saenz pena
# Processing Record 45 of Set 8 | kuzino
# Processing Record 46 of Set 8 | hamilton
# Processing Record 47 of Set 8 | geelong
# Processing Record 48 of Set 8 | troitskoye
# Processing Record 49 of Set 8 | kutum
# Processing Record 50 of Set 8 | biu
# Processing Record 1 of Set 9 | ararat
# Processing Record 2 of Set 9 | watertown
# Processing Record 3 of Set 9 | guanay
# Processing Record 4 of Set 9 | iranshahr
# Processing Record 5 of Set 9 | mao
# Processing Record 6 of Set 9 | nuuk
# Processing Record 7 of Set 9 | queanbeyan
# Processing Record 8 of Set 9 | ayan
# Processing Record 9 of Set 9 | batagay-alyta
# Processing Record 10 of Set 9 | sistranda
# Processing Record 11 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 12 of Set 9 | arman
# Processing Record 13 of Set 9 | koson
# Processing Record 14 of Set 9 | viedma
# Processing Record 15 of Set 9 | bababe
# City not found. Skipping...
# Processing Record 16 of Set 9 | innisfail
# Processing Record 17 of Set 9 | constantine
# Processing Record 18 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 19 of Set 9 | tougue
# Processing Record 20 of Set 9 | loikaw
# Processing Record 21 of Set 9 | seabra
# Processing Record 22 of Set 9 | bani
# Processing Record 23 of Set 9 | kaitangata
# Processing Record 24 of Set 9 | dauphin
# Processing Record 25 of Set 9 | ananas
# Processing Record 26 of Set 9 | guerrero negro
# Processing Record 27 of Set 9 | hebertville
# City not found. Skipping...
# Processing Record 28 of Set 9 | champerico
# Processing Record 29 of Set 9 | novo aripuana
# Processing Record 30 of Set 9 | vestbygda
# City not found. Skipping...
# Processing Record 31 of Set 9 | izazi
# Processing Record 32 of Set 9 | gouyave
# Processing Record 33 of Set 9 | quatre cocos
# Processing Record 34 of Set 9 | urucara
# Processing Record 35 of Set 9 | gamboma
# Processing Record 36 of Set 9 | matara
# Processing Record 37 of Set 9 | cap malheureux
# Processing Record 38 of Set 9 | buckeye
# Processing Record 39 of Set 9 | clifton
# Processing Record 40 of Set 9 | puerto colombia
# Processing Record 41 of Set 9 | karratha
# Processing Record 42 of Set 9 | sikandra rao
# Processing Record 43 of Set 9 | krasnaya gora
# Processing Record 44 of Set 9 | lalganj
# Processing Record 45 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 46 of Set 9 | taoudenni
# Processing Record 47 of Set 9 | yar-sale
# Processing Record 48 of Set 9 | eenhana
# Processing Record 49 of Set 9 | guadalupe y calvo
# Processing Record 50 of Set 9 | half moon bay
# Processing Record 1 of Set 10 | camamu
# Processing Record 2 of Set 10 | qaqortoq
# Processing Record 3 of Set 10 | tayu
# Processing Record 4 of Set 10 | miri
# Processing Record 5 of Set 10 | warrington
# Processing Record 6 of Set 10 | mehamn
# Processing Record 7 of Set 10 | luhyny
# Processing Record 8 of Set 10 | zihuatanejo
# Processing Record 9 of Set 10 | baykit
# Processing Record 10 of Set 10 | rovaniemi
# Processing Record 11 of Set 10 | martinopolis
# Processing Record 12 of Set 10 | piryion
# City not found. Skipping...
# Processing Record 13 of Set 10 | north bend
# Processing Record 14 of Set 10 | nevers
# Processing Record 15 of Set 10 | ocos
# Processing Record 16 of Set 10 | kasulu
# Processing Record 17 of Set 10 | skjervoy
# Processing Record 18 of Set 10 | dingle
# Processing Record 19 of Set 10 | belaya gora
# Processing Record 20 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 10 | kropotkin
# Processing Record 22 of Set 10 | benalla
# Processing Record 23 of Set 10 | gold coast
# Processing Record 24 of Set 10 | lavrentiya
# Processing Record 25 of Set 10 | bardiyah
# Processing Record 26 of Set 10 | pacific grove
# Processing Record 27 of Set 10 | requena
# Processing Record 28 of Set 10 | naze
# Processing Record 29 of Set 10 | bereda
# Processing Record 30 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 10 | sobolevo
# Processing Record 32 of Set 10 | valleyview
# Processing Record 33 of Set 10 | vanavara
# Processing Record 34 of Set 10 | worthington
# Processing Record 35 of Set 10 | tonantins
# Processing Record 36 of Set 10 | acapulco
# Processing Record 37 of Set 10 | khani
# Processing Record 38 of Set 10 | sawtell
# Processing Record 39 of Set 10 | novobelokatay
# Processing Record 40 of Set 10 | buchanan
# Processing Record 41 of Set 10 | anqing
# Processing Record 42 of Set 10 | alta floresta
# Processing Record 43 of Set 10 | dubai
# Processing Record 44 of Set 10 | sabzevar
# Processing Record 45 of Set 10 | port hedland
# Processing Record 46 of Set 10 | ierapetra
# Processing Record 47 of Set 10 | humaita
# Processing Record 48 of Set 10 | cooma
# Processing Record 49 of Set 10 | vestmannaeyjar
# Processing Record 50 of Set 10 | jieshi
# Processing Record 1 of Set 11 | esmeraldas
# Processing Record 2 of Set 11 | tigil
# Processing Record 3 of Set 11 | bandarbeyla
# Processing Record 4 of Set 11 | kyren
# Processing Record 5 of Set 11 | ikalamavony
# Processing Record 6 of Set 11 | ejura
# Processing Record 7 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 11 | tongliao
# Processing Record 9 of Set 11 | tiznit
# Processing Record 10 of Set 11 | maridi
# Processing Record 11 of Set 11 | lincoln
# Processing Record 12 of Set 11 | mabaruma
# Processing Record 13 of Set 11 | lagoa
# Processing Record 14 of Set 11 | jurm
# Processing Record 15 of Set 11 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 16 of Set 11 | ketchikan
# Processing Record 17 of Set 11 | osorno
# Processing Record 18 of Set 11 | yilan
# Processing Record 19 of Set 11 | akyab
# Processing Record 20 of Set 11 | corinto
# Processing Record 21 of Set 11 | bumba
# Processing Record 22 of Set 11 | rocha
# Processing Record 23 of Set 11 | nouadhibou
# Processing Record 24 of Set 11 | gali
# Processing Record 25 of Set 11 | mingshui
# Processing Record 26 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 11 | yurya
# City not found. Skipping...
# Processing Record 28 of Set 11 | nevelsk
# Processing Record 29 of Set 11 | road town
# Processing Record 30 of Set 11 | weligama
# Processing Record 31 of Set 11 | dembi dolo
# Processing Record 32 of Set 11 | sembe
# Processing Record 33 of Set 11 | jizan
# Processing Record 34 of Set 11 | kuytun
# Processing Record 35 of Set 11 | turukhansk
# Processing Record 36 of Set 11 | laiagam
# City not found. Skipping...
# Processing Record 37 of Set 11 | honningsvag
# Processing Record 38 of Set 11 | muriwai beach
# Processing Record 39 of Set 11 | barra da estiva
# Processing Record 40 of Set 11 | ciudad guayana
# Processing Record 41 of Set 11 | sand springs
# Processing Record 42 of Set 11 | cravo norte
# Processing Record 43 of Set 11 | dalby
# Processing Record 44 of Set 11 | zyryanka
# Processing Record 45 of Set 11 | grand-santi
# Processing Record 46 of Set 11 | san patricio
# Processing Record 47 of Set 11 | pereira barreto
# Processing Record 48 of Set 11 | xingtai
# Processing Record 49 of Set 11 | cockburn town
# Processing Record 50 of Set 11 | ombessa
# Processing Record 1 of Set 12 | tkvarcheli
# City not found. Skipping...
# Processing Record 2 of Set 12 | tupik
# Processing Record 3 of Set 12 | berlevag
# Processing Record 4 of Set 12 | amurzet
# Processing Record 5 of Set 12 | mitzic
# Processing Record 6 of Set 12 | saint-pierre
# Processing Record 7 of Set 12 | adrar
# Processing Record 8 of Set 12 | lebork
# Processing Record 9 of Set 12 | imeni babushkina
# Processing Record 10 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 11 of Set 12 | san luis
# Processing Record 12 of Set 12 | ternate
# Processing Record 13 of Set 12 | katrineholm
# Processing Record 14 of Set 12 | darhan
# Processing Record 15 of Set 12 | sakakah
# Processing Record 16 of Set 12 | bahir dar
# Processing Record 17 of Set 12 | korla
# Processing Record 18 of Set 12 | ancud
# Processing Record 19 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 12 | baglan
# Processing Record 21 of Set 12 | general pico
# Processing Record 22 of Set 12 | mount isa
# Processing Record 23 of Set 12 | kargopol
# Processing Record 24 of Set 12 | wangqing
# Processing Record 25 of Set 12 | tessalit
# Processing Record 26 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 12 | jadu
# Processing Record 28 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 29 of Set 12 | leningradskiy
# Processing Record 30 of Set 12 | mnogovershinnyy
# Processing Record 31 of Set 12 | aklavik
# Processing Record 32 of Set 12 | cedar rapids
# Processing Record 33 of Set 12 | husavik
# Processing Record 34 of Set 12 | sevierville
# Processing Record 35 of Set 12 | isla mujeres
# Processing Record 36 of Set 12 | tadine
# Processing Record 37 of Set 12 | ziyamet
# City not found. Skipping...
# Processing Record 38 of Set 12 | berezovyy
# Processing Record 39 of Set 12 | la ronge
# Processing Record 40 of Set 12 | bodinayakkanur
# Processing Record 41 of Set 12 | ahvaz
# Processing Record 42 of Set 12 | wewak
# Processing Record 43 of Set 12 | braco do norte
# Processing Record 44 of Set 12 | nsanje
# Processing Record 45 of Set 12 | puro
# Processing Record 46 of Set 12 | chicama
# Processing Record 47 of Set 12 | kirakira
# Processing Record 48 of Set 12 | chateaubelair
# Processing Record 49 of Set 12 | pierre
# Processing Record 50 of Set 12 | clyde river
# Processing Record 1 of Set 13 | sokolo
# Processing Record 2 of Set 13 | honiara
# Processing Record 3 of Set 13 | damara
# Processing Record 4 of Set 13 | uchaly
# Processing Record 5 of Set 13 | luderitz
# Processing Record 6 of Set 13 | charlottetown
# Processing Record 7 of Set 13 | urengoy
# Processing Record 8 of Set 13 | ranong
# Processing Record 9 of Set 13 | terra santa
# Processing Record 10 of Set 13 | rafraf
# Processing Record 11 of Set 13 | genhe
# Processing Record 12 of Set 13 | storforshei
# Processing Record 13 of Set 13 | atlantis
# Processing Record 14 of Set 13 | camacha
# Processing Record 15 of Set 13 | sur
# Processing Record 16 of Set 13 | putla
# City not found. Skipping...
# Processing Record 17 of Set 13 | belyy yar
# Processing Record 18 of Set 13 | wajima
# Processing Record 19 of Set 13 | liverpool
# Processing Record 20 of Set 13 | ahipara
# Processing Record 21 of Set 13 | marand
# Processing Record 22 of Set 13 | la roda
# Processing Record 23 of Set 13 | dwarka
# Processing Record 24 of Set 13 | gambiran
# Processing Record 25 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 26 of Set 13 | shillong
# Processing Record 27 of Set 13 | hanumangarh
# Processing Record 28 of Set 13 | labuhan
# Processing Record 29 of Set 13 | fortuna
# Processing Record 30 of Set 13 | fomboni
# Processing Record 31 of Set 13 | crestview
# Processing Record 32 of Set 13 | dicabisagan
# Processing Record 33 of Set 13 | aleksandrovka
# Processing Record 34 of Set 13 | bachaquero
# Processing Record 35 of Set 13 | pozo colorado
# Processing Record 36 of Set 13 | canutama
# Processing Record 37 of Set 13 | takab
# Processing Record 38 of Set 13 | leshukonskoye
# Processing Record 39 of Set 13 | suao
# City not found. Skipping...
# Processing Record 40 of Set 13 | sola
# Processing Record 41 of Set 13 | kushiro
# Processing Record 42 of Set 13 | westport
# Processing Record 43 of Set 13 | chimala
# Processing Record 44 of Set 13 | uusikaupunki
# Processing Record 45 of Set 13 | dapaong
# Processing Record 46 of Set 13 | chapais
# Processing Record 47 of Set 13 | raichur
# Processing Record 48 of Set 13 | kruisfontein
# Processing Record 49 of Set 13 | cassia
# Processing Record 50 of Set 13 | svetlyy
# Processing Record 1 of Set 14 | katsuura
# Processing Record 2 of Set 14 | warri
# Processing Record 3 of Set 14 | aguilas
# Processing Record 4 of Set 14 | seagoville
# Processing Record 5 of Set 14 | tura
# Processing Record 6 of Set 14 | muzhi
# Processing Record 7 of Set 14 | haines junction
# Processing Record 8 of Set 14 | kysyl-syr
# Processing Record 9 of Set 14 | jiblah
# Processing Record 10 of Set 14 | alofi
# Processing Record 11 of Set 14 | abbeville
# Processing Record 12 of Set 14 | sao joao da barra
# Processing Record 13 of Set 14 | sambava
# Processing Record 14 of Set 14 | san isidro
# Processing Record 15 of Set 14 | hokitika
# Processing Record 16 of Set 14 | krasnoselkup
# Processing Record 17 of Set 14 | phan thiet
# Processing Record 18 of Set 14 | ixtlan del rio
# Processing Record 19 of Set 14 | nemuro
# Processing Record 20 of Set 14 | pedernales
# Processing Record 21 of Set 14 | xichang
# Processing Record 22 of Set 14 | hobyo
# Processing Record 23 of Set 14 | afyonkarahisar
# Processing Record 24 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 14 | damietta
# Processing Record 26 of Set 14 | ruteng
# Processing Record 27 of Set 14 | irgakly
# Processing Record 28 of Set 14 | uchiza
# Processing Record 29 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 30 of Set 14 | mantena
# Processing Record 31 of Set 14 | ust-omchug
# Processing Record 32 of Set 14 | aykhal
# Processing Record 33 of Set 14 | tera
# Processing Record 34 of Set 14 | calatayud
# Processing Record 35 of Set 14 | surt
# Processing Record 36 of Set 14 | asau
# Processing Record 37 of Set 14 | brae
# Processing Record 38 of Set 14 | lufilufi
# Processing Record 39 of Set 14 | gasa
# Processing Record 40 of Set 14 | mandan
# Processing Record 41 of Set 14 | opuwo
# Processing Record 42 of Set 14 | kargil
# Processing Record 43 of Set 14 | conceicao do araguaia
# Processing Record 44 of Set 14 | banda aceh
# Processing Record 45 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 46 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 14 | zavodoukovsk
# Processing Record 48 of Set 14 | moose factory
# Processing Record 49 of Set 14 | tucuman
# Processing Record 50 of Set 14 | deder
# Processing Record 1 of Set 15 | ngukurr
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 643

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City      Lat       Lng Current Description  Max Temp  \
# 0             Ostrovnoy  68.0531   39.5131     overcast clouds     46.49
# 1                  Lebu -37.6167  -73.6500          light rain     50.43
# 2              Benguela -12.5763   13.4055       broken clouds     71.40
# 3               College  64.8569 -147.8028          few clouds     36.59
# 4               Kavieng  -2.5744  150.7967       broken clouds     84.20
# 5            Bredasdorp -34.5322   20.0403    scattered clouds     57.16
# 6  Vila Franca Do Campo  37.7167  -25.4333     overcast clouds     69.19
# 7             Tazovskiy  67.4667   78.7000     overcast clouds     35.20
# 8               Mataura -46.1927  168.8643     overcast clouds     45.48
# 9              Bengkulu  -3.8004  102.2655          light rain     80.83
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        79          90       21.14      RU
# 1        95         100       15.17      CL
# 2        81          77        1.79      AO
# 3        88          20        3.44      US
# 4        72          80       11.74      PG
# 5        67          27       10.13      ZA
# 6        88          90        9.01      PT
# 7        74          94        6.58      RU
# 8        68          85        8.50      NZ
# 9        82          66        7.27      ID

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Current Description', 'Max Temp', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
city_data_df = city_data_df.reindex(["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description" ], axis=1)
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ostrovnoy      RU  68.0531   39.5131     46.49        79          90
# 1             Lebu      CL -37.6167  -73.6500     50.43        95         100
# 2         Benguela      AO -12.5763   13.4055     71.40        81          77
# 3          College      US  64.8569 -147.8028     36.59        88          20
# 4          Kavieng      PG  -2.5744  150.7967     84.20        72          80
# ..             ...     ...      ...       ...       ...       ...         ...
# 638     Banda Aceh      ID   5.5577   95.3222     83.37        72          99
# 639   Zavodoukovsk      RU  56.5042   66.5515     53.20        41         100
# 640  Moose Factory      CA  51.2585  -80.6094     42.80        93         100
# 641        Tucuman      AR -26.8241  -65.2226     60.80        67         100
# 642          Deder      ET   9.3167   41.4500     67.75        41          35
#
#      Wind Speed Current Description
# 0         21.14     overcast clouds
# 1         15.17          light rain
# 2          1.79       broken clouds
# 3          3.44          few clouds
# 4         11.74       broken clouds
# ..          ...                 ...
# 638       14.03     overcast clouds
# 639        8.81     overcast clouds
# 640        9.22     overcast clouds
# 641       10.36     overcast clouds
# 642        4.94    scattered clouds
#
# [643 rows x 9 columns]

# %%
#Create the output file (CSV).
csv_weather_file = "WeatherPy_Database.csv"
#Export the City_Data into a CSV.
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
